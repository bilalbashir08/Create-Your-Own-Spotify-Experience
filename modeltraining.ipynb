# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.feature import Normalizer
from pyspark.sql.functions import rand
from pyspark.ml.linalg import Vectors, VectorUDT
from pyspark.sql.functions import udf
from pyspark.ml.feature import StringIndexer
from pyspark.sql.types import ArrayType, DoubleType
from pyspark.sql.functions import size, max as max_, array
from annoy import AnnoyIndex
from pyspark.sql.functions import col
import numpy as np
import librosa
import os
import gc
import audioread
from audioread.exceptions import NoBackendError

# %%
def extract_mfcc(audio_path):
    try:
        audio, sample_rate = librosa.load(audio_path, sr=None)
        mfcc_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=100).mean(axis=1)
        return mfcc_features.tolist()
    except NoBackendError as e:
        print("No suitable audio backend found:", e)

# %%
def load_data_from_mongodb(spark_session, input_uri):
    df = spark_session.read.format("com.mongodb.spark.sql.DefaultSource").option("uri", input_uri).load()
    return df

# %%
array_to_vector_udf = udf(lambda arr: Vectors.dense(arr), VectorUDT())
def create_feature_vector(df):
    df = df.withColumn("features", array_to_vector_udf(df["mfcc_features"]))
    return df

# %%
def normalize_features(df):
    normalizer = Normalizer(inputCol="features", outputCol="normalized_features")
    df = normalizer.transform(df)
    return df

# %%
def train_recommendation_model(df, num_trees=10):
    features = df.select("features").collect()
    dim = len(features[0].features)

    print("Dimension of features:", dim)

    annoy_index = AnnoyIndex(dim, 'angular')
    for i, row in enumerate(features):
        vector = row.features
        vector_length = len(vector)
        if vector_length != dim:
            print("Vector length mismatch at index", i, "- Expected:", dim, "Got:", vector_length)
            continue
        annoy_index.add_item(i, vector)

    annoy_index.build(num_trees)
    annoy_index.save('music_recommendation.ann')

    return annoy_index

# %%
def load_trained_annoy_index():
    annoy_index = AnnoyIndex(100, 'angular')
    annoy_index.load('music_recommendation.ann')
    return annoy_index

# %%
def evaluate_model(model, test_data):
    return

# %%
def split_train_test_data(df, train_ratio=0.8):
    train_data = df.filter(rand() < train_ratio)
    test_data = df.subtract(train_data)
    return train_data, test_data

# %%
def add_user_id_column(df, user_id_column):
    indexer = StringIndexer(inputCol=user_id_column, outputCol="user_id")
    indexed_df = indexer.fit(df).transform(df)
    return indexed_df

# %%
def find_nearest_neighbors(annoy_index, target_vector, k=5):
    nearest_neighbors = annoy_index.get_nns_by_vector(target_vector, k)
    return nearest_neighbors

# %%
input_uri = "mongodb://localhost:27017/bda.audio_features"

spark = SparkSession.builder \
    .appName("MusicRecommendationModel") \
    .config("spark.mongodb.input.uri", input_uri) \
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:3.0.2") \
    .getOrCreate()
# Out:
# 24/05/12 00:25:13 WARN Utils: Your hostname, moaz-HP-ProBook-440-G5 resolves to a loopback address: 127.0.1.1; using 192.168.10.5 instead (on interface wlp2s0)
# 24/05/12 00:25:13 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/home/moaz/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/moaz/.ivy2/cache
# The jars for the packages stored in: /home/moaz/.ivy2/jars
# org.mongodb.spark#mongo-spark-connector_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-8bb65ed2-02a9-4846-b149-28dd59acb3a3;1.0
# 	confs: [default]
# 	found org.mongodb.spark#mongo-spark-connector_2.12;3.0.2 in central
# 	found org.mongodb#mongodb-driver-sync;4.0.5 in central
# 	found org.mongodb#bson;4.0.5 in central
# 	found org.mongodb#mongodb-driver-core;4.0.5 in central
# :: resolution report :: resolve 251ms :: artifacts dl 16ms
# 	:: modules in use:
# 	org.mongodb#bson;4.0.5 from central in [default]
# 	org.mongodb#mongodb-driver-core;4.0.5 from central in [default]
# 	org.mongodb#mongodb-driver-sync;4.0.5 from central in [default]
# 	org.mongodb.spark#mongo-spark-connector_2.12;3.0.2 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   4   |   0   |   0   |   0   ||   4   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-8bb65ed2-02a9-4846-b149-28dd59acb3a3
# 	confs: [default]
# 	0 artifacts copied, 4 already retrieved (0kB/14ms)
# 24/05/12 00:25:15 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/05/12 00:25:17 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
def process_audio_file(audio_path):
    audio_features = extract_mfcc(audio_path)
    audio_features_df = spark.createDataFrame([(audio_path, audio_features)], ["audio_path", "mfcc_features"])
    audio_features_df = create_feature_vector(audio_features_df)
    audio_features_df = normalize_features(audio_features_df)
    return audio_features_df

# %%
df = load_data_from_mongodb(spark, input_uri)
df.show()
# Out:
# +--------------------+--------------------+--------------------+
# |                 _id|          audio_path|       mfcc_features|
# +--------------------+--------------------+--------------------+
# |{663f94f62f15021b...|DataSet/067/06732...|[-206.81163024902...|
# |{663f94f62f15021b...|DataSet/067/06705...|[-252.43721008300...|
# |{663f94f62f15021b...|DataSet/067/06759...|[-218.26321411132...|
# |{663f94f62f15021b...|DataSet/067/06776...|[-214.04769897460...|
# |{663f94f62f15021b...|DataSet/067/06774...|[-138.56770324707...|
# |{663f94f62f15021b...|DataSet/067/06716...|[7.75728654861450...|
# |{663f94f62f15021b...|DataSet/096/09671...|[-164.58990478515...|
# |{663f94f62f15021b...|DataSet/096/09616...|[-142.40655517578...|
# |{663f94f62f15021b...|DataSet/096/09627...|[-340.62588500976...|
# |{663f94f62f15021b...|DataSet/096/09602...|[-125.80657958984...|
# |{663f94f62f15021b...|DataSet/096/09664...|[-214.04400634765...|
# |{663f94f62f15021b...|DataSet/096/09693...|[-64.120185852050...|
# |{663f94f62f15021b...|DataSet/090/09083...|[-217.72148132324...|
# |{663f94f62f15021b...|DataSet/096/09650...|[-93.024314880371...|
# |{663f94f62f15021b...|DataSet/090/09089...|[-187.50482177734...|
# |{663f94f62f15021b...|DataSet/090/09080...|[-221.96925354003...|
# |{663f94f62f15021b...|DataSet/090/09031...|[-122.44226837158...|
# |{663f94f62f15021b...|DataSet/117/11745...|[-230.09861755371...|
# |{663f94f62f15021b...|DataSet/090/09059...|[-212.25135803222...|
# |{663f94f62f15021b...|DataSet/117/11718...|[-223.60984802246...|
# +--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
df = create_feature_vector(df)
df.show()
# Out:
# [Stage 2:>                                                          (0 + 1) / 1]
# +--------------------+--------------------+--------------------+--------------------+
# |                 _id|          audio_path|       mfcc_features|            features|
# +--------------------+--------------------+--------------------+--------------------+
# |{663f94f62f15021b...|DataSet/067/06732...|[-206.81163024902...|[-206.81163024902...|
# |{663f94f62f15021b...|DataSet/067/06705...|[-252.43721008300...|[-252.43721008300...|
# |{663fb9652f15021b...|DataSet/150/15087...|[4.94097757339477...|[4.94097757339477...|[0.05306505308970...|103849.0|
# |{663fbbde2f15021b...|DataSet/140/14053...|[-41.086067199707...|[-41.086067199707...|[-0.2013687718047...| 96193.0|
# |{663fbe1a2f15021b...|DataSet/092/09241...|[-132.82696533203...|[-132.82696533203...|[-0.6167573751535...| 62071.0|
# |{663f9c892f15021b...|DataSet/004/00445...|[-345.92324829101...|[-345.92324829101...|[-0.9290801740214...|  2649.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------+
# only showing top 20 rows
# 24/05/12 00:25:58 WARN DAGScheduler: Broadcasting large task binary with size 5.3 MiB

# %%
selected_train_data = train_data.select("user_id", "normalized_features", "audio_path")
selected_train_data = selected_train_data.withColumnRenamed("normalized_features", "features")
selected_train_data.show()
# Out:
# 24/05/12 00:25:58 WARN DAGScheduler: Broadcasting large task binary with size 5.3 MiB
# +-------+--------------------+--------------------+
# |user_id|            features|          audio_path|
# +-------+--------------------+--------------------+
# |45921.0|[-0.7371349737352...|DataSet/067/06732...|
# |45705.0|[-0.8747194103813...|DataSet/067/06705...|
# |46148.0|[-0.6919126717382...|DataSet/067/06759...|
# |46279.0|[-0.8262855612396...|DataSet/067/06776...|
# |45763.0|[0.06079818933145...|DataSet/067/06716...|
# |64636.0|[-0.6678599763898...|DataSet/096/09671...|
# |64329.0|[-0.6462094523192...|DataSet/096/09616...|
# |64351.0|[-0.8703146004582...|DataSet/096/09627...|
# |64562.0|[-0.7333173542057...|DataSet/096/09664...|
# |60952.0|[-0.7540288007909...|DataSet/090/09083...|
# |64482.0|[-0.4635524587552...|DataSet/096/09650...|
# |60986.0|[-0.7108369184895...|DataSet/090/09089...|
# |60937.0|[-0.7867684544029...|DataSet/090/09080...|
# |60721.0|[-0.5967708371627...|DataSet/090/09031...|
# |78323.0|[-0.7470270151995...|DataSet/117/11745...|
# |78228.0|[-0.7159934470662...|DataSet/117/11731...|
# |78328.0|[-0.6174248860759...|DataSet/117/11746...|
# |20154.0|[-0.9646541538990...|DataSet/031/03188...|
# |78479.0|[-0.9360287231378...|DataSet/117/11774...|
# |78567.0|[-0.7088573598950...|DataSet/117/11785...|
# +-------+--------------------+--------------------+
# only showing top 20 rows

# %%
model = train_recommendation_model(selected_train_data)
# Out:
# Dimension of features: 100
# Vector length mismatch at index 556 - Expected: 100 Got: 0
# Vector length mismatch at index 631 - Expected: 100 Got: 0
# Vector length mismatch at index 697 - Expected: 100 Got: 0
# Vector length mismatch at index 793 - Expected: 100 Got: 0
# Vector length mismatch at index 864 - Expected: 100 Got: 0
# Vector length mismatch at index 1390 - Expected: 100 Got: 0
# Vector length mismatch at index 1618 - Expected: 100 Got: 0
# Vector length mismatch at index 1657 - Expected: 100 Got: 0
# Vector length mismatch at index 2125 - Expected: 100 Got: 0
# Vector length mismatch at index 2170 - Expected: 100 Got: 0
# Vector length mismatch at index 2352 - Expected: 100 Got: 0
# Vector length mismatch at index 3106 - Expected: 100 Got: 0
# Vector length mismatch at index 3592 - Expected: 100 Got: 0
# Vector length mismatch at index 5182 - Expected: 100 Got: 0
# Vector length mismatch at index 5470 - Expected: 100 Got: 0
# Vector length mismatch at index 5849 - Expected: 100 Got: 0
# Vector length mismatch at index 7337 - Expected: 100 Got: 0
# Vector length mismatch at index 7476 - Expected: 100 Got: 0
# Vector length mismatch at index 8026 - Expected: 100 Got: 0
# Vector length mismatch at index 8520 - Expected: 100 Got: 0
# Vector length mismatch at index 11468 - Expected: 100 Got: 0
# Vector length mismatch at index 11574 - Expected: 100 Got: 0
# Vector length mismatch at index 12855 - Expected: 100 Got: 0
# Vector length mismatch at index 12902 - Expected: 100 Got: 0
# Vector length mismatch at index 13301 - Expected: 100 Got: 0
# Vector length mismatch at index 13313 - Expected: 100 Got: 0
# Vector length mismatch at index 13564 - Expected: 100 Got: 0
# Vector length mismatch at index 17336 - Expected: 100 Got: 0
# Vector length mismatch at index 17951 - Expected: 100 Got: 0
# Vector length mismatch at index 18260 - Expected: 100 Got: 0
# Vector length mismatch at index 18960 - Expected: 100 Got: 0
# Vector length mismatch at index 20452 - Expected: 100 Got: 0
# Vector length mismatch at index 20528 - Expected: 100 Got: 0
# Vector length mismatch at index 20547 - Expected: 100 Got: 0
# Vector length mismatch at index 20559 - Expected: 100 Got: 0
# Vector length mismatch at index 21418 - Expected: 100 Got: 0
# Vector length mismatch at index 23160 - Expected: 100 Got: 0
# Vector length mismatch at index 25720 - Expected: 100 Got: 0
# Vector length mismatch at index 25723 - Expected: 100 Got: 0
# Vector length mismatch at index 27962 - Expected: 100 Got: 0
# Vector length mismatch at index 28229 - Expected: 100 Got: 0
# Vector length mismatch at index 28649 - Expected: 100 Got: 0
# Vector length mismatch at index 28917 - Expected: 100 Got: 0
# Vector length mismatch at index 29044 - Expected: 100 Got: 0
# Vector length mismatch at index 30916 - Expected: 100 Got: 0
# Vector length mismatch at index 32505 - Expected: 100 Got: 0
# Vector length mismatch at index 32638 - Expected: 100 Got: 0
# Vector length mismatch at index 32807 - Expected: 100 Got: 0
# Vector length mismatch at index 34415 - Expected: 100 Got: 0
# Vector length mismatch at index 34680 - Expected: 100 Got: 0
# Vector length mismatch at index 36540 - Expected: 100 Got: 0
# Vector length mismatch at index 37592 - Expected: 100 Got: 0
# Vector length mismatch at index 42888 - Expected: 100 Got: 0
# Vector length mismatch at index 43246 - Expected: 100 Got: 0
# Vector length mismatch at index 43548 - Expected: 100 Got: 0
# Vector length mismatch at index 43635 - Expected: 100 Got: 0
# Vector length mismatch at index 43641 - Expected: 100 Got: 0
# Vector length mismatch at index 43940 - Expected: 100 Got: 0
# Vector length mismatch at index 44073 - Expected: 100 Got: 0
# Vector length mismatch at index 44285 - Expected: 100 Got: 0
# Vector length mismatch at index 44672 - Expected: 100 Got: 0
# Vector length mismatch at index 44862 - Expected: 100 Got: 0
# Vector length mismatch at index 45058 - Expected: 100 Got: 0
# Vector length mismatch at index 45333 - Expected: 100 Got: 0
# Vector length mismatch at index 45475 - Expected: 100 Got: 0
# Vector length mismatch at index 46686 - Expected: 100 Got: 0
# Vector length mismatch at index 47400 - Expected: 100 Got: 0
# Vector length mismatch at index 47590 - Expected: 100 Got: 0
# Vector length mismatch at index 47917 - Expected: 100 Got: 0
# Vector length mismatch at index 48814 - Expected: 100 Got: 0
# Vector length mismatch at index 50561 - Expected: 100 Got: 0
# Vector length mismatch at index 51937 - Expected: 100 Got: 0
# Vector length mismatch at index 54284 - Expected: 100 Got: 0
# Vector length mismatch at index 54780 - Expected: 100 Got: 0
# Vector length mismatch at index 55052 - Expected: 100 Got: 0
# Vector length mismatch at index 56181 - Expected: 100 Got: 0
# Vector length mismatch at index 56182 - Expected: 100 Got: 0
# Vector length mismatch at index 56303 - Expected: 100 Got: 0
# Vector length mismatch at index 56658 - Expected: 100 Got: 0
# Vector length mismatch at index 56916 - Expected: 100 Got: 0
# Vector length mismatch at index 56968 - Expected: 100 Got: 0
# Vector length mismatch at index 57054 - Expected: 100 Got: 0
# Vector length mismatch at index 57064 - Expected: 100 Got: 0
# Vector length mismatch at index 57148 - Expected: 100 Got: 0
# Vector length mismatch at index 57315 - Expected: 100 Got: 0
# Vector length mismatch at index 57647 - Expected: 100 Got: 0
# Vector length mismatch at index 58589 - Expected: 100 Got: 0
# Vector length mismatch at index 58802 - Expected: 100 Got: 0
# Vector length mismatch at index 59117 - Expected: 100 Got: 0
# Vector length mismatch at index 62062 - Expected: 100 Got: 0
# Vector length mismatch at index 63015 - Expected: 100 Got: 0
# Vector length mismatch at index 63413 - Expected: 100 Got: 0
# Vector length mismatch at index 64187 - Expected: 100 Got: 0
# Vector length mismatch at index 64661 - Expected: 100 Got: 0
# Vector length mismatch at index 64814 - Expected: 100 Got: 0
# Vector length mismatch at index 64842 - Expected: 100 Got: 0
# Vector length mismatch at index 64956 - Expected: 100 Got: 0
# Vector length mismatch at index 65150 - Expected: 100 Got: 0
# Vector length mismatch at index 65392 - Expected: 100 Got: 0
# Vector length mismatch at index 65470 - Expected: 100 Got: 0
# Vector length mismatch at index 66200 - Expected: 100 Got: 0
# Vector length mismatch at index 66329 - Expected: 100 Got: 0
# Vector length mismatch at index 66690 - Expected: 100 Got: 0
# Vector length mismatch at index 66757 - Expected: 100 Got: 0
# Vector length mismatch at index 66850 - Expected: 100 Got: 0
# Vector length mismatch at index 66933 - Expected: 100 Got: 0
# Vector length mismatch at index 68782 - Expected: 100 Got: 0
# Vector length mismatch at index 69221 - Expected: 100 Got: 0
# Vector length mismatch at index 70910 - Expected: 100 Got: 0
# Vector length mismatch at index 71851 - Expected: 100 Got: 0
# Vector length mismatch at index 75250 - Expected: 100 Got: 0
# Vector length mismatch at index 76599 - Expected: 100 Got: 0
# Vector length mismatch at index 76701 - Expected: 100 Got: 0
# Vector length mismatch at index 76871 - Expected: 100 Got: 0
# Vector length mismatch at index 77164 - Expected: 100 Got: 0
# Vector length mismatch at index 77396 - Expected: 100 Got: 0
# Vector length mismatch at index 77551 - Expected: 100 Got: 0
# Vector length mismatch at index 77671 - Expected: 100 Got: 0
# Vector length mismatch at index 77696 - Expected: 100 Got: 0
# Vector length mismatch at index 77906 - Expected: 100 Got: 0
# Vector length mismatch at index 77964 - Expected: 100 Got: 0
# Vector length mismatch at index 78181 - Expected: 100 Got: 0
# Vector length mismatch at index 78325 - Expected: 100 Got: 0
# Vector length mismatch at index 78352 - Expected: 100 Got: 0
# Vector length mismatch at index 78373 - Expected: 100 Got: 0
# Vector length mismatch at index 78397 - Expected: 100 Got: 0
# Vector length mismatch at index 78546 - Expected: 100 Got: 0
# Vector length mismatch at index 78570 - Expected: 100 Got: 0
# Vector length mismatch at index 78572 - Expected: 100 Got: 0
# Vector length mismatch at index 78715 - Expected: 100 Got: 0
# Vector length mismatch at index 80378 - Expected: 100 Got: 0
# Vector length mismatch at index 80514 - Expected: 100 Got: 0
# Vector length mismatch at index 81567 - Expected: 100 Got: 0
# Vector length mismatch at index 81739 - Expected: 100 Got: 0
# Vector length mismatch at index 82037 - Expected: 100 Got: 0
# Vector length mismatch at index 82200 - Expected: 100 Got: 0
# Vector length mismatch at index 82308 - Expected: 100 Got: 0
# Vector length mismatch at index 82664 - Expected: 100 Got: 0
# Vector length mismatch at index 83266 - Expected: 100 Got: 0
# Vector length mismatch at index 83625 - Expected: 100 Got: 0
# Vector length mismatch at index 84557 - Expected: 100 Got: 0

# %%
audio_path = "Sampled_Dataset/002/002108.mp3"
audio_features_df = process_audio_file(audio_path)
annoy_index = load_trained_annoy_index()

# %%
target_features = audio_features_df.collect()[0]["features"]
nearest_neighbors = find_nearest_neighbors(annoy_index, target_features, 100)
neighbors_data = train_data.select("audio_path").collect()
nearest_neighbor_paths = [neighbors_data[i]["audio_path"] for i in nearest_neighbors]

print("Top 100 Nearest Neighbors:")
for i in range(100):
    print(f"Neighbor {i + 1}:")
    print(f"Index: {nearest_neighbors[i]}")
    print(f"Path: {nearest_neighbor_paths[i]}\n")
# Out:
# Top 100 Nearest Neighbors:
# Neighbor 1:
# Index: 1225
# Path: DataSet/117/117994.mp3
#
# Neighbor 2:
# Index: 37609
# Path: DataSet/032/032480.mp3
#
# Neighbor 3:
# Index: 57213
# Path: DataSet/014/014306.mp3
#
# Neighbor 4:
# Index: 11853
# Path: DataSet/082/082695.mp3
#
# Neighbor 5:
# Index: 9345
# Path: DataSet/029/029227.mp3
#
# Neighbor 6:
# Index: 34406
# Path: DataSet/114/114573.mp3
#
# Neighbor 7:
# Index: 51913
# Path: DataSet/050/050507.mp3
#
# Neighbor 8:
# Index: 41180
# Path: DataSet/138/138668.mp3
#
# Neighbor 9:
# Index: 5452
# Path: DataSet/019/019271.mp3
#
# Neighbor 10:
# Index: 79220
# Path: DataSet/000/000648.mp3
#
# Neighbor 11:
# Index: 36865
# Path: DataSet/032/032100.mp3
#
# Neighbor 12:
# Index: 11207
# Path: DataSet/001/001308.mp3
#
# Neighbor 13:
# Index: 81549
# Path: DataSet/092/092882.mp3
#
# Neighbor 14:
# Index: 31718
# Path: DataSet/133/133446.mp3
#
# Neighbor 15:
# Index: 19124
# Path: DataSet/124/124091.mp3
#
# Neighbor 16:
# Index: 49742
# Path: DataSet/060/060718.mp3
#
# Neighbor 17:
# Index: 26500
# Path: DataSet/044/044029.mp3
#
# Neighbor 18:
# Index: 80804
# Path: DataSet/149/149544.mp3
#
# Neighbor 19:
# Index: 48510
# Path: DataSet/042/042736.mp3
#
# Neighbor 20:
# Index: 59207
# Path: DataSet/106/106468.mp3
#
# Neighbor 21:
# Index: 61758
# Path: DataSet/048/048193.mp3
#
# Neighbor 22:
# Index: 28135
# Path: DataSet/044/044065.mp3
#
# Neighbor 23:
# Index: 79006
# Path: DataSet/039/039292.mp3
#
# Neighbor 24:
# Index: 30034
# Path: DataSet/091/091894.mp3
#
# Neighbor 25:
# Index: 39649
# Path: DataSet/135/135178.mp3
#
# Neighbor 26:
# Index: 59257
# Path: DataSet/066/066896.mp3
#
# Neighbor 27:
# Index: 919
# Path: DataSet/067/067041.mp3
#
# Neighbor 28:
# Index: 57232
# Path: DataSet/087/087115.mp3
#
# Neighbor 29:
# Index: 4633
# Path: DataSet/003/003973.mp3
#
# Neighbor 30:
# Index: 25684
# Path: DataSet/034/034346.mp3
#
# Neighbor 31:
# Index: 79297
# Path: DataSet/006/006355.mp3
#
# Neighbor 32:
# Index: 67371
# Path: DataSet/073/073696.mp3
#
# Neighbor 33:
# Index: 7711
# Path: DataSet/029/029044.mp3
#
# Neighbor 34:
# Index: 68399
# Path: DataSet/022/022498.mp3
#
# Neighbor 35:
# Index: 23315
# Path: DataSet/081/081985.mp3
#
# Neighbor 36:
# Index: 70616
# Path: DataSet/008/008558.mp3
#
# Neighbor 37:
# Index: 24025
# Path: DataSet/054/054998.mp3
#
# Neighbor 38:
# Index: 71713
# Path: DataSet/064/064564.mp3
#
# Neighbor 39:
# Index: 40679
# Path: DataSet/118/118404.mp3
#
# Neighbor 40:
# Index: 79115
# Path: DataSet/149/149077.mp3
#
# Neighbor 41:
# Index: 80086
# Path: DataSet/000/000144.mp3
#
# Neighbor 42:
# Index: 36496
# Path: DataSet/032/032527.mp3
#
# Neighbor 43:
# Index: 42484
# Path: DataSet/051/051456.mp3
#
# Neighbor 44:
# Index: 26700
# Path: DataSet/155/155290.mp3
#
# Neighbor 45:
# Index: 24073
# Path: DataSet/054/054175.mp3
#
# Neighbor 46:
# Index: 6291
# Path: DataSet/065/065076.mp3
#
# Neighbor 47:
# Index: 39924
# Path: DataSet/135/135678.mp3
#
# Neighbor 48:
# Index: 57193
# Path: DataSet/014/014822.mp3
#
# Neighbor 49:
# Index: 22606
# Path: DataSet/105/105002.mp3
#
# Neighbor 50:
# Index: 67862
# Path: DataSet/017/017994.mp3
#
# Neighbor 51:
# Index: 53572
# Path: DataSet/109/109333.mp3
#
# Neighbor 52:
# Index: 67132
# Path: DataSet/073/073742.mp3
#
# Neighbor 53:
# Index: 45400
# Path: DataSet/101/101172.mp3
#
# Neighbor 54:
# Index: 831
# Path: DataSet/031/031797.mp3
#
# Neighbor 55:
# Index: 58138
# Path: DataSet/066/066816.mp3
#
# Neighbor 56:
# Index: 73803
# Path: DataSet/131/131639.mp3
#
# Neighbor 57:
# Index: 47521
# Path: DataSet/063/063995.mp3
#
# Neighbor 58:
# Index: 53538
# Path: DataSet/049/049708.mp3
#
# Neighbor 59:
# Index: 64576
# Path: DataSet/026/026488.mp3
#
# Neighbor 60:
# Index: 32137
# Path: DataSet/055/055292.mp3
#
# Neighbor 61:
# Index: 31058
# Path: DataSet/013/013784.mp3
#
# Neighbor 62:
# Index: 12408
# Path: DataSet/130/130205.mp3
#
# Neighbor 63:
# Index: 75995
# Path: DataSet/010/010236.mp3
#
# Neighbor 64:
# Index: 17479
# Path: DataSet/075/075665.mp3
#
# Neighbor 65:
# Index: 34514
# Path: DataSet/035/035179.mp3
#
# Neighbor 66:
# Index: 49553
# Path: DataSet/042/042077.mp3
#
# Neighbor 67:
# Index: 5862
# Path: DataSet/080/080839.mp3
#
# Neighbor 68:
# Index: 32696
# Path: DataSet/059/059876.mp3
#
# Neighbor 69:
# Index: 10652
# Path: DataSet/082/082021.mp3
#
# Neighbor 70:
# Index: 81163
# Path: DataSet/052/052111.mp3
#
# Neighbor 71:
# Index: 60060
# Path: DataSet/048/048472.mp3
#
# Neighbor 72:
# Index: 35908
# Path: DataSet/058/058290.mp3
#
# Neighbor 73:
# Index: 10243
# Path: DataSet/001/001287.mp3
#
# Neighbor 74:
# Index: 69469
# Path: DataSet/121/121834.mp3
#
# Neighbor 75:
# Index: 44250
# Path: DataSet/072/072700.mp3
#
# Neighbor 76:
# Index: 67909
# Path: DataSet/084/084411.mp3
#
# Neighbor 77:
# Index: 18369
# Path: DataSet/085/085895.mp3
#
# Neighbor 78:
# Index: 57119
# Path: DataSet/125/125855.mp3
#
# Neighbor 79:
# Index: 52424
# Path: DataSet/079/079164.mp3
#
# Neighbor 80:
# Index: 691
# Path: DataSet/067/067132.mp3
#
# Neighbor 81:
# Index: 28040
# Path: DataSet/018/018625.mp3
#
# Neighbor 82:
# Index: 56014
# Path: DataSet/087/087145.mp3
#
# Neighbor 83:
# Index: 2842
# Path: DataSet/003/003429.mp3
#
# Neighbor 84:
# Index: 23520
# Path: DataSet/081/081042.mp3
#
# Neighbor 85:
# Index: 79101
# Path: DataSet/000/000359.mp3
#
# Neighbor 86:
# Index: 65680
# Path: DataSet/151/151908.mp3
#
# Neighbor 87:
# Index: 5915
# Path: DataSet/007/007073.mp3
#
# Neighbor 88:
# Index: 9044
# Path: DataSet/065/065773.mp3
#
# Neighbor 89:
# Index: 3067
# Path: DataSet/003/003345.mp3
#
# Neighbor 90:
# Index: 6302
# Path: DataSet/141/141561.mp3
#
# Neighbor 91:
# Index: 9341
# Path: DataSet/029/029304.mp3
#
# Neighbor 92:
# Index: 39446
# Path: DataSet/028/028176.mp3
#
# Neighbor 93:
# Index: 56603
# Path: DataSet/125/125410.mp3
#
# Neighbor 94:
# Index: 70554
# Path: DataSet/064/064482.mp3
#
# Neighbor 95:
# Index: 51713
# Path: DataSet/123/123706.mp3
#
# Neighbor 96:
# Index: 83471
# Path: DataSet/113/113535.mp3
#
# Neighbor 97:
# Index: 6065
# Path: DataSet/041/041074.mp3
#
# Neighbor 98:
# Index: 61031
# Path: DataSet/068/068494.mp3
#
# Neighbor 99:
# Index: 80783
# Path: DataSet/052/052195.mp3
#
# Neighbor 100:
# Index: 22938
# Path: DataSet/105/105765.mp3
